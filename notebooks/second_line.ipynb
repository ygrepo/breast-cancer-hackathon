# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
pd.set_option('large_repr', 'truncate')
pd.set_option('display.float_format', lambda x: '%.3f' % x)
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
from pathlib import Path

from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score, roc_curve, roc_auc_score,confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression

from typing import Tuple

import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
DATA_PATH = Path("../data/")
DOCUMENTATION_PATH = Path("../documentation")
RANDOM_STATE_PARAMETER = 42
TEST_SIZE = .25

# %%
data = pd.read_csv(DATA_PATH / "Sample-data.csv")

# %%
data.head()
# Out:
#   ABBREV         CLAIM_ID  PATIENT_ID       NDC  PROVIDER_ID DIAGNOSIS_CODE  \
# 0    TAM 461404000000.000    29360529  93078486      7655074            NaN
# 1    TAM 463120000000.000    29360529  93078486      7655074            NaN
# 2    TAM 466104000000.000    29360529  93078486      7655074            NaN
# 3    TAM 467195000000.000    29360529  93078486      7655074            NaN
# 4    TAM 467851000000.000    29360529  93078486      7655074            NaN
#
#    DIAG_VERS_TYP_ID  PAYER_PLAN_ID  REFILL_CODE  DSPNSD_QTY  ...  \
# 0               nan              0            1         180  ...
# 1               nan              0            2         180  ...
# 2               nan              0            3         180  ...
# 3               nan              0            4         180  ...
# 4               nan              0            0         180  ...
#
#            DRUG_NAME BGI  DRUG_STRENGTH  DRUG_FORM PACK_QTY  \
# 0  TAMOXIFEN CITRATE   G          10 MG       TABS        1
# 1  TAMOXIFEN CITRATE   G          10 MG       TABS        1
# 2  TAMOXIFEN CITRATE   G          10 MG       TABS        1
# 3  TAMOXIFEN CITRATE   G          10 MG       TABS        1
# 4  TAMOXIFEN CITRATE   G          10 MG       TABS        1
#
#   PACKAGE_DESCRIPTION  MANUFACTURER USC_CD               USC_DESC  \
# 0              BOTTLE  MAYNE PHARMA  35350  ANTINEO ANTIESTROGENS
# 1              BOTTLE  MAYNE PHARMA  35350  ANTINEO ANTIESTROGENS
# 2              BOTTLE  MAYNE PHARMA  35350  ANTINEO ANTIESTROGENS
# 3              BOTTLE  MAYNE PHARMA  35350  ANTINEO ANTIESTROGENS
# 4              BOTTLE  MAYNE PHARMA  35350  ANTINEO ANTIESTROGENS
#
#   NDC_START_DATE
# 0      2/20/2003
# 1      2/20/2003
# 2      2/20/2003
# 3      2/20/2003
# 4      2/20/2003
#
# [5 rows x 26 columns]

# %%
drugs = pd.read_csv(DATA_PATH / "RX_all_10brands.csv")

# %%
drugs.head()
# Out:
#   ABBREV         CLAIM_ID  PATIENT_ID       NDC  PROVIDER_ID DIAGNOSIS_CODE  \
# 0    IBR 510585000000.000  1351981404  69018721     14982008        C50.912
# 1    IBR 510486000000.000  1422703010  69018921      7575271            NaN
# 2    IBR 510436000000.000  1351981404  69018721     14982008        C50.912
# 3    IBR 510332000000.000   842577505  69018721      8077849        C50.919
# 4    IBR 510332000000.000   709614881  69018921      7878515        C50.411
#
#    DIAG_VERS_TYP_ID  PAYER_PLAN_ID  REFILL_CODE  DSPNSD_QTY  ...  DRUG_NAME  \
# 0             2.000 7000560388.000        1.000      14.000  ...    IBRANCE
# 1            -1.000   20400128.000        1.000      21.000  ...    IBRANCE
# 2             2.000 7000560388.000        1.000      14.000  ...    IBRANCE
# 3             2.000   45050001.000        1.000      14.000  ...    IBRANCE
# 4             2.000   11629999.000        0.000      21.000  ...    IBRANCE
#
#   BGI  DRUG_STRENGTH  DRUG_FORM PACK_QTY PACKAGE_DESCRIPTION MANUFACTURER  \
# 0   T          75 MG       CAPS        1              BOTTLE  PFIZER U.S.
# 1   T         125 MG       CAPS        1              BOTTLE  PFIZER U.S.
# 2   T          75 MG       CAPS        1              BOTTLE  PFIZER U.S.
# 3   T          75 MG       CAPS        1              BOTTLE  PFIZER U.S.
# 4   T         125 MG       CAPS        1              BOTTLE  PFIZER U.S.
#
#   USC_CD        USC_DESC NDC_START_DATE
# 0  35113  CDK INHIBITORS       2/5/2015
# 1  35113  CDK INHIBITORS       2/5/2015
# 2  35113  CDK INHIBITORS       2/5/2015
# 3  35113  CDK INHIBITORS       2/5/2015
# 4  35113  CDK INHIBITORS       2/5/2015
#
# [5 rows x 26 columns]
